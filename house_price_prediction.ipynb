# %% [markdown]
# <a href="https://colab.research.google.com/github/kharalsantosh/House-Price-Prediction/blob/main/house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Sample dataset
# House sizes
x = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700])

 # Prices
y = np.array([245000, 312000, 279000, 308000, 199000, 219000, 405000, 324000, 319000, 255000])

# %%
# Initialize parameters
m, b = 0, 0
learning_rate = 0.0000001
epochs = 1000

# %%
# Gradient Descent
for i in range(epochs):
    y_pred = m * x + b
    dm = (-2/len(x)) * np.sum(x * (y - y_pred))
    db = (-2/len(x)) * np.sum(y - y_pred)
    m -= learning_rate * dm
    b -= learning_rate * db

# %%
# Predict price for a new house
new_size = 2000
predicted_price = m * new_size + b
print(f"Predicted price for a {new_size} sq ft house: ${predicted_price:.2f}")
# Out:
# Predicted price for a 2000 sq ft house: $328299.40

# %%
# Plot
plt.scatter(x, y, color="blue", label="Data points")
plt.plot(x, m * x + b, color="red", label="Regression line")
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price ($)")
plt.title("House Price Prediction")
plt.legend()
plt.show()
